# %% [markdown]
# # MetaKernel Python Demo
#
# This notebook demonstrates the magics available in [MetaKernel](https://github.com/Calysto/metakernel).
# MetaKernel provides a rich set of line and cell magics that work across any kernel built on it.

# %% [markdown]
# ## List Available Magics
#
# Use `%lsmagic` to see all installed line and cell magics.

# %%
# %lsmagic
# Out:
# Available line magics:
# %activity  %blockly  %cd  %connect_info  %conversation  %dot  %download  %edit  %get  %help  %html  %include  %install  %install_magic  %javascript  %jigsaw  %kernel  %kx  %latex  %load  %ls  %lsmagic  %macro  %magic  %matplotlib  %parallel  %plot  %pmap  %px  %python  %reload_magics  %restart  %run  %scheme  %set  %shell
#
# Available cell magics:
# %%activity  %%brain  %%conversation  %%debug  %%dot  %%file  %%help  %%html  %%javascript  %%kx  %%latex  %%macro  %%pipe  %%processing  %%px  %%python  %%scheme  %%shell  %%show  %%time  %%tutor

# %% [markdown]
# ## Shell Magics
#
# `%shell` runs a single shell command. `%%shell` runs the entire cell as a shell script.
# You can also use `!` and `!!` as shorthand.

# %%
# %shell echo "Hello from the shell!"
# Out:
# Hello from the shell!

# %%
# %%shell
# echo "Current directory: $(pwd)"
# echo "Python version: $(python --version)"
# Out:
# Current directory: /Users/stevensilvester/workspace/metakernel/examples
# Python version: Python 3.10.19

# %% [markdown]
# ## File System Magics
#
# `%ls` lists directory contents. `%cd` changes the working directory.

# %%
# %ls .
# Out:
# ./
#   Calysto Processing.ipynb
#   workspace2.xml
#   Jigsaw in IPython.ipynb
#   workspace2.png
#   workspace1.xml
#   workspace1.png
#   Mandelbrot.ipynb
#   processing1.xml
#   workspace2.html
#   echo_kernel.ipynb
#   processing1.html
#   Processing Magic in IPython.ipynb
#   temp.txt
#   SAS_metakernel_example.ipynb
#   workspace1.html
#   metakernel_python_demo.ipynb
#   Tutor Magic in IPython.ipynb

# %% [markdown]
# ## Writing and Running Files
#
# `%%file` writes the cell contents to a file. `%run` executes a file.

# %%
# %%file /tmp/hello.py
def greet(name):
    return f"Hello, {name}!"

print(greet("MetaKernel"))
# Out:
# Created file '/tmp/hello.py'.

# %%
# %run /tmp/hello.py
# Out:
# Hello, MetaKernel!

# %% [markdown]
# ## Timing Magic
#
# `%%time` reports how long a cell takes to execute.

# %%
# %%time
total = sum(range(1_000_000))
print(total)
# Out:
# 499999500000
# Time: 0.014487981796264648 seconds.

# %% [markdown]
# ## HTML Magic
#
# `%html` and `%%html` render output as HTML in the browser.

# %%
# %html <b>Bold</b>, <i>italic</i>, and <span style="color:steelblue">colored</span> text.
# Out:
# <b>Bold</b>, <i>italic</i>, and <span style="color:steelblue">colored</span> text.

# %%
# %%html
# <table border="1" style="border-collapse:collapse; padding:6px">
#   <tr><th>Magic</th><th>Description</th></tr>
#   <tr><td>%lsmagic</td><td>List all magics</td></tr>
#   <tr><td>%shell</td><td>Run a shell command</td></tr>
#   <tr><td>%%file</td><td>Write cell to file</td></tr>
#   <tr><td>%%time</td><td>Time cell execution</td></tr>
#   <tr><td>%%latex</td><td>Render as LaTeX</td></tr>
# </table>
# Out:
# <table border="1" style="border-collapse:collapse; padding:6px">
#   <tr><th>Magic</th><th>Description</th></tr>
#   <tr><td>%lsmagic</td><td>List all magics</td></tr>
#   <tr><td>%shell</td><td>Run a shell command</td></tr>
#   <tr><td>%%file</td><td>Write cell to file</td></tr>
#   <tr><td>%%time</td><td>Time cell execution</td></tr>
#   <tr><td>%%latex</td><td>Render as LaTeX</td></tr>
# </table>

# %% [markdown]
# ## LaTeX Magic
#
# `%latex` and `%%latex` render mathematical notation using LaTeX.

# %%
# %latex $E = mc^2$
# Out:
# $E = mc^2$

# %%
# %%latex
# $$\int_{-\infty}^{\infty} e^{-x^2} dx = \sqrt{\pi}$$
#
# $$F(x) = \sum_{n=0}^{\infty} \frac{f^{(n)}(a)}{n!}(x-a)^n$$
# Out:
# $$\int_{-\infty}^{\infty} e^{-x^2} dx = \sqrt{\pi}$$
#
# $$F(x) = \sum_{n=0}^{\infty} \frac{f^{(n)}(a)}{n!}(x-a)^n$$

# %% [markdown]
# ## Set and Get Variables
#
# `%set` assigns a Python value to a kernel variable. `%get` retrieves it.

# %%
# %set x 42
# %set items [1, 2, 3, 4, 5]
# Out:
# Error in calling magic 'set' on line:
#     'int' object has no attribute 'strip'
#     args: ['x', 42]
#     kwargs: {}
# Traceback (most recent call last):
#   File "/Users/stevensilvester/.cache/uv/archive-v0/-v4gJJjs-BVDmWfgIoAB5/lib/python3.10/site-packages/metakernel/magic.py", line 99, in call_magic
#     func(*args, **kwargs)
#   File "/Users/stevensilvester/.cache/uv/archive-v0/-v4gJJjs-BVDmWfgIoAB5/lib/python3.10/site-packages/metakernel/magics/set_magic.py", line 20, in line_set
#     value = self.kernel.do_execute_direct(value)
#   File "/Users/stevensilvester/.cache/uv/archive-v0/-v4gJJjs-BVDmWfgIoAB5/lib/python3.10/site-packages/metakernel_python/__init__.py", line 55, in do_execute_direct
#     return python_magic.eval(code.strip())
# AttributeError: 'int' object has no attribute 'strip'
# %set VARIABLE VALUE - set a variable in the kernel.
#
# This line magic is used to set a variable to a Python value.
#
# Examples:
#     %set x 42
#     %set x [1, 2, 3]

# %%
# %get x

# %%
# %get items

# %% [markdown]
# ## Macro Magic
#
# `%%macro` defines a reusable named macro. `%macro NAME` executes it.

# %%
# %%macro hello
# print("Hello from a macro!")
# print("The answer is", 6 * 7)

# %%
# %macro hello
# Out:
# Hello from a macro!
# The answer is
# 42

# %% [markdown]
# ## Tutor Magic
#
# `%%tutor` visualizes code execution step-by-step using [Python Tutor](https://pythontutor.com).

# %%
# %%tutor --language=python3
# def factorial(n):
#     if n <= 1:
#         return 1
#     return n * factorial(n - 1)
#
# result = factorial(5)
# print(result)
# Out:
#         <iframe
#             width="100%"
#             height="500"
#             src="https://pythontutor.com/iframe-embed.html#code=def%20factorial%28n%29%3A%0A%20%20%20%20if%20n%20%3C%3D%201%3A%0A%20%20%20%20%20%20%20%20return%201%0A%20%20%20%20return%20n%20%2A%20factorial%28n%20-%201%29%0A%0Aresult%20%3D%20factorial%285%29%0Aprint%28result%29&origin=opt-frontend.js&cumulative=false&heapPrimitives=false&textReferences=false&py=3&rawInputLstJSON=%5B%5D&curInstr=0&codeDivWidth=350&codeDivHeight=400"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
